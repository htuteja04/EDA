# %%
import pandas as pd

# %%
Reg = pd.read_excel('../Datasets/WP_Demographics/Regional.xlsx')

# %%
Reg.head()
# Out:
#   Unnamed: 0 Unnamed: 1                            Unnamed: 2 Unnamed: 3  \
# 0      Index    Variant  Region, subregion, country or area *      Notes
# 1       1589  Estimates                                AFRICA        NaN
# 2       1590  Estimates                                AFRICA        NaN
# 3       1591  Estimates                                AFRICA        NaN
# 4       1592  Estimates                                AFRICA        NaN
#
#       Unnamed: 4       Unnamed: 5       Unnamed: 6   Unnamed: 7 Unnamed: 8  \
# 0  Location code  ISO3 Alpha-code  ISO2 Alpha-code  SDMX code**       Type
# 1            903              NaN              NaN            2     Region
# 2            903              NaN              NaN            2     Region
# 3            903              NaN              NaN            2     Region
# 4            903              NaN              NaN            2     Region
#
#     Unnamed: 9  ...                                        Unnamed: 55  \
# ...

# %%
cols = Reg.iloc[0].values

# %%
cols[2]
# Out:
# 'Region, subregion, country or area *'

# %%
Reg.columns = cols

# %%
Reg.head()
# Out:
#    Index    Variant  Region, subregion, country or area *  Notes  \
# 0  Index    Variant  Region, subregion, country or area *  Notes
# 1   1589  Estimates                                AFRICA    NaN
# 2   1590  Estimates                                AFRICA    NaN
# 3   1591  Estimates                                AFRICA    NaN
# 4   1592  Estimates                                AFRICA    NaN
#
#    Location code  ISO3 Alpha-code  ISO2 Alpha-code  SDMX code**    Type  \
# 0  Location code  ISO3 Alpha-code  ISO2 Alpha-code  SDMX code**    Type
# 1            903              NaN              NaN            2  Region
# 2            903              NaN              NaN            2  Region
# 3            903              NaN              NaN            2  Region
# 4            903              NaN              NaN            2  Region
#
#    Parent code  ...  \
# 0  Parent code  ...
# 1         1840  ...
# 2         1840  ...
# 3         1840  ...
# 4         1840  ...
#
# ...

# %%
Reg = Reg[1:]

# %%
Reg.head()
# Out:
#   Index    Variant Region, subregion, country or area * Notes Location code  \
# 1  1589  Estimates                               AFRICA   NaN           903
# 2  1590  Estimates                               AFRICA   NaN           903
# 3  1591  Estimates                               AFRICA   NaN           903
# 4  1592  Estimates                               AFRICA   NaN           903
# 5  1593  Estimates                               AFRICA   NaN           903
#
#   ISO3 Alpha-code ISO2 Alpha-code SDMX code**    Type Parent code  ...  \
# 1             NaN             NaN           2  Region        1840  ...
# 2             NaN             NaN           2  Region        1840  ...
# 3             NaN             NaN           2  Region        1840  ...
# 4             NaN             NaN           2  Region        1840  ...
# 5             NaN             NaN           2  Region        1840  ...
#
# ...

# %%
Reg = Reg.rename(columns={"Region, subregion, country or area *":"Region"})

# %%
Reg.shape
# Out:
# (432, 65)

# %%
Reg.head()
# Out:
#   Index    Variant  Region Notes Location code ISO3 Alpha-code  \
# 1  1589  Estimates  AFRICA   NaN           903             NaN
# 2  1590  Estimates  AFRICA   NaN           903             NaN
# 3  1591  Estimates  AFRICA   NaN           903             NaN
# 4  1592  Estimates  AFRICA   NaN           903             NaN
# 5  1593  Estimates  AFRICA   NaN           903             NaN
#
#   ISO2 Alpha-code SDMX code**    Type Parent code  ...  \
# 1             NaN           2  Region        1840  ...
# 2             NaN           2  Region        1840  ...
# 3             NaN           2  Region        1840  ...
# 4             NaN           2  Region        1840  ...
# 5             NaN           2  Region        1840  ...
#
#   Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)  \
# 1                                            676.242
# 2                                            673.073
# 3                                            667.352
# ...

# %%
Reg.Region.unique()
# Out:
# array(['AFRICA', 'ASIA', 'EUROPE', 'LATIN AMERICA AND THE CARIBBEAN',
#        'NORTHERN AMERICA', 'OCEANIA'], dtype=object)

# %%
Reg.iloc[:5,0:10]
# Out:
#   Index    Variant  Region Notes Location code ISO3 Alpha-code  \
# 1  1589  Estimates  AFRICA   NaN           903             NaN
# 2  1590  Estimates  AFRICA   NaN           903             NaN
# 3  1591  Estimates  AFRICA   NaN           903             NaN
# 4  1592  Estimates  AFRICA   NaN           903             NaN
# 5  1593  Estimates  AFRICA   NaN           903             NaN
#
#   ISO2 Alpha-code SDMX code**    Type Parent code
# 1             NaN           2  Region        1840
# 2             NaN           2  Region        1840
# 3             NaN           2  Region        1840
# 4             NaN           2  Region        1840
# 5             NaN           2  Region        1840

# %%
Reg = Reg.iloc[:,2:]

# %%
Reg.iloc[:5,0:10]
# Out:
#    Region Notes Location code ISO3 Alpha-code ISO2 Alpha-code SDMX code**  \
# 1  AFRICA   NaN           903             NaN             NaN           2
# 2  AFRICA   NaN           903             NaN             NaN           2
# 3  AFRICA   NaN           903             NaN             NaN           2
# 4  AFRICA   NaN           903             NaN             NaN           2
# 5  AFRICA   NaN           903             NaN             NaN           2
#
#      Type Parent code  Year Total Population, as of 1 January (thousands)
# 1  Region        1840  1950                                    225120.311
# 2  Region        1840  1951                                    229978.205
# 3  Region        1840  1952                                    234989.784
# 4  Region        1840  1953                                    240182.336
# 5  Region        1840  1954                                    245492.559

# %%
Reg = Reg.drop(Reg.iloc[:,1:8],axis=1)

# %%
Reg.iloc[:5,0:10]
# Out:
#    Region  Year Total Population, as of 1 January (thousands)  \
# 1  AFRICA  1950                                    225120.311
# 2  AFRICA  1951                                    229978.205
# 3  AFRICA  1952                                    234989.784
# 4  AFRICA  1953                                    240182.336
# 5  AFRICA  1954                                    245492.559
#
#   Total Population, as of 1 July (thousands)  \
# 1                                 227549.258
# 2                                 232483.995
# 3                                  237586.06
# 4                                 242837.448
# 5                                 248244.771
#
#   Male Population, as of 1 July (thousands)  \
# 1                                113474.172
# 2                                115915.005
# 3                                118442.586
# 4                                121050.757
# 5                                123736.856
#
# ...

# %%
Reg.iloc[:5,10:20]
# Out:
#   Rate of Natural Change (per 1,000 population) Population Change (thousands)  \
# 1                                        21.466                      4857.894
# 2                                        21.793                      5011.579
# 3                                        22.271                      5192.552
# 4                                        22.718                      5310.223
# 5                                        22.979                      5504.423
#
#   Population Growth Rate (percentage) Population Annual Doubling Time (years)  \
# 1                               2.135                                  32.466
# 2                               2.156                                   32.15
# 3                               2.186                                  31.708
# 4                               2.187                                  31.694
# 5                               2.217                                  31.265
#
# ...

# %%
Reg.iloc[:5,20:30]
# Out:
#   Sex Ratio at Birth (males per 100 female births) Total Deaths (thousands)  \
# 1                                            103.9                 6062.986
# 2                                            103.9                 6132.451
# 3                                            103.9                 6154.863
# 4                                            103.9                 6188.063
# 5                                            103.9                 6233.523
#
#   Male Deaths (thousands) Female Deaths (thousands)  \
# 1                3152.087                  2910.899
# 2                3187.351                    2945.1
# 3                 3199.46                  2955.403
# 4                3216.657                  2971.406
# 5                 3252.43                  2981.093
#
#   Crude Death Rate (deaths per 1,000 population)  \
# 1                                         26.636
# 2                                          26.37
# ...

# %%
Reg.iloc[:5,30:40]
# Out:
#   Female Life Expectancy at Age 15 (years)  \
# 1                                   44.771
# 2                                   44.867
# 3                                    45.05
# 4                                   45.278
# 5                                    45.46
#
#   Life Expectancy at Age 65, both sexes (years)  \
# 1                                        10.658
# 2                                        10.675
# 3                                        10.737
# 4                                        10.797
# 5                                        10.842
#
#   Male Life Expectancy at Age 65 (years)  \
# 1                                 10.353
# 2                                 10.354
# 3                                 10.409
# 4                                 10.461
# 5                                  10.48
#
#   Female Life Expectancy at Age 65 (years)  \
# 1                                   10.929
# 2                                    10.96
# ...

# %%
Reg.iloc[:5,40:50]
# Out:
#   Under-Five Deaths, under age 5 (thousands)  \
# 1                                   3440.484
# 2                                   3471.106
# 3                                   3475.048
# 4                                   3482.896
# 5                                   3488.113
#
#   Under-Five Mortality (deaths under age 5 per 1,000 live births)  \
# 1                                            323.904
# 2                                            319.432
# 3                                            313.062
# 4                                            306.924
# 5                                            300.897
#
#   Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births)  \
# 1                                            500.908
# 2                                            496.578
# 3                                            489.666
# 4                                            483.243
# 5                                            478.505
#
# ...

# %%
Reg.iloc[:5,50:56]
# Out:
#   Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15)  \
# 1                                            292.231
# 2                                            290.545
# 3                                              287.6
# 4                                            283.818
# 5                                             280.89
#
#   Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15)  \
# 1                                            448.248
# 2                                            446.659
# 3                                            443.249
# 4                                            438.779
# 5                                            439.324
#
#   Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15)  \
# 1                                            474.317
# 2                                             473.07
# ...

# %%
Reg.to_csv('../Datasets/WP_Demographics/Reg-modified.csv')

# %% [markdown]
# ![WP_Demographics%20%281%29.png](attachment:WP_Demographics%20%281%29.png)

# %%
USA = pd.read_excel('../Datasets/WP_Demographics/USA.xlsx')

# %%
USA.head()
# Out:
#   Unnamed: 0 Unnamed: 1                            Unnamed: 2 Unnamed: 3  \
# 0      Index    Variant  Region, subregion, country or area *      Notes
# 1      18509  Estimates              United States of America         31
# 2      18510  Estimates              United States of America         31
# 3      18511  Estimates              United States of America         31
# 4      18512  Estimates              United States of America         31
#
#       Unnamed: 4       Unnamed: 5       Unnamed: 6   Unnamed: 7    Unnamed: 8  \
# 0  Location code  ISO3 Alpha-code  ISO2 Alpha-code  SDMX code**          Type
# 1            840              USA               US          840  Country/Area
# 2            840              USA               US          840  Country/Area
# 3            840              USA               US          840  Country/Area
# 4            840              USA               US          840  Country/Area
#
# ...

# %%
cols = USA.iloc[0].values

# %%
USA.columns = cols

# %%
USA = USA[1:]

# %%
USA.head()
# Out:
#    Index    Variant Region, subregion, country or area * Notes Location code  \
# 1  18509  Estimates             United States of America    31           840
# 2  18510  Estimates             United States of America    31           840
# 3  18511  Estimates             United States of America    31           840
# 4  18512  Estimates             United States of America    31           840
# 5  18513  Estimates             United States of America    31           840
#
#   ISO3 Alpha-code ISO2 Alpha-code SDMX code**          Type Parent code  ...  \
# 1             USA              US         840  Country/Area         905  ...
# 2             USA              US         840  Country/Area         905  ...
# 3             USA              US         840  Country/Area         905  ...
# 4             USA              US         840  Country/Area         905  ...
# 5             USA              US         840  Country/Area         905  ...
#
# ...

# %%
USA.iloc[:,:10]
# Out:
#     Index    Variant Region, subregion, country or area * Notes Location code  \
# 1   18509  Estimates             United States of America    31           840
# 2   18510  Estimates             United States of America    31           840
# 3   18511  Estimates             United States of America    31           840
# 4   18512  Estimates             United States of America    31           840
# 5   18513  Estimates             United States of America    31           840
# ..    ...        ...                                  ...   ...           ...
# 68  18576  Estimates             United States of America    31           840
# 69  18577  Estimates             United States of America    31           840
# 70  18578  Estimates             United States of America    31           840
# 71  18579  Estimates             United States of America    31           840
# 72  18580  Estimates             United States of America    31           840
#
# ...

# %%
USA = USA.rename(columns={"Region, subregion, country or area *":"Country"})

# %%
USA.head()
# Out:
#    Index    Variant                   Country Notes Location code  \
# 1  18509  Estimates  United States of America    31           840
# 2  18510  Estimates  United States of America    31           840
# 3  18511  Estimates  United States of America    31           840
# 4  18512  Estimates  United States of America    31           840
# 5  18513  Estimates  United States of America    31           840
#
#   ISO3 Alpha-code ISO2 Alpha-code SDMX code**          Type Parent code  ...  \
# 1             USA              US         840  Country/Area         905  ...
# 2             USA              US         840  Country/Area         905  ...
# 3             USA              US         840  Country/Area         905  ...
# 4             USA              US         840  Country/Area         905  ...
# 5             USA              US         840  Country/Area         905  ...
#
#   Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)  \
# ...

# %%
USA.iloc[:,:10]
# Out:
#     Index    Variant                   Country Notes Location code  \
# 1   18509  Estimates  United States of America    31           840
# 2   18510  Estimates  United States of America    31           840
# 3   18511  Estimates  United States of America    31           840
# 4   18512  Estimates  United States of America    31           840
# 5   18513  Estimates  United States of America    31           840
# ..    ...        ...                       ...   ...           ...
# 68  18576  Estimates  United States of America    31           840
# 69  18577  Estimates  United States of America    31           840
# 70  18578  Estimates  United States of America    31           840
# 71  18579  Estimates  United States of America    31           840
# 72  18580  Estimates  United States of America    31           840
#
#    ISO3 Alpha-code ISO2 Alpha-code SDMX code**          Type Parent code
# 1              USA              US         840  Country/Area         905
# ...

# %%
USA.iloc[:,10:20]
# Out:
#     Year Total Population, as of 1 January (thousands)  \
# 1   1950                                    147095.867
# 2   1951                                    149467.233
# 3   1952                                    151729.673
# 4   1953                                    154153.781
# 5   1954                                    156748.617
# ..   ...                                           ...
# 68  2017                                    328553.489
# 69  2018                                    331028.972
# 70  2019                                    333251.103
# 71  2020                                    335388.238
# 72  2021                                    336495.769
#
#    Total Population, as of 1 July (thousands)  \
# 1                                   148281.55
# 2                                  150598.453
# 3                                  152941.727
# 4                                  155451.199
# 5                                  158205.873
# ...

# %%
USA = USA.iloc[:,10:]

# %%
USA.head()
# Out:
#    Year Total Population, as of 1 January (thousands)  \
# 1  1950                                    147095.867
# 2  1951                                    149467.233
# 3  1952                                    151729.673
# 4  1953                                    154153.781
# 5  1954                                    156748.617
#
#   Total Population, as of 1 July (thousands)  \
# 1                                  148281.55
# 2                                 150598.453
# 3                                 152941.727
# 4                                 155451.199
# 5                                 158205.873
#
#   Male Population, as of 1 July (thousands)  \
# 1                                 73516.095
# 2                                 74784.499
# 3                                 76079.283
# 4                                 77221.443
# 5                                 78577.893
#
#   Female Population, as of 1 July (thousands)  \
# ...

# %%
USA.to_csv('../Datasets/WP_Demographics/USA-mod.csv')

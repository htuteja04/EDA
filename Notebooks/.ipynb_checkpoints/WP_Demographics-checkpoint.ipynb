# %%
import pandas as pd

# %%
Reg = pd.read_excel('../Datasets/WP_Demographics/Regional.xlsx')

# %%
Reg.head()
# Out:
#   Unnamed: 0 Unnamed: 1                            Unnamed: 2 Unnamed: 3  \
# 0      Index    Variant  Region, subregion, country or area *      Notes
# 1       1589  Estimates                                AFRICA        NaN
# 2       1590  Estimates                                AFRICA        NaN
# 3       1591  Estimates                                AFRICA        NaN
# 4       1592  Estimates                                AFRICA        NaN
#
#       Unnamed: 4       Unnamed: 5       Unnamed: 6   Unnamed: 7 Unnamed: 8  \
# 0  Location code  ISO3 Alpha-code  ISO2 Alpha-code  SDMX code**       Type
# 1            903              NaN              NaN            2     Region
# 2            903              NaN              NaN            2     Region
# 3            903              NaN              NaN            2     Region
# 4            903              NaN              NaN            2     Region
#
#     Unnamed: 9  ...                                        Unnamed: 55  \
# ...

# %%
cols = Reg.iloc[0].values

# %%
cols[2]
# Out:
# 'Region, subregion, country or area *'

# %%
Reg.columns = cols

# %%
Reg.head()
# Out:
#    Index    Variant  Region, subregion, country or area *  Notes  \
# 0  Index    Variant  Region, subregion, country or area *  Notes
# 1   1589  Estimates                                AFRICA    NaN
# 2   1590  Estimates                                AFRICA    NaN
# 3   1591  Estimates                                AFRICA    NaN
# 4   1592  Estimates                                AFRICA    NaN
#
#    Location code  ISO3 Alpha-code  ISO2 Alpha-code  SDMX code**    Type  \
# 0  Location code  ISO3 Alpha-code  ISO2 Alpha-code  SDMX code**    Type
# 1            903              NaN              NaN            2  Region
# 2            903              NaN              NaN            2  Region
# 3            903              NaN              NaN            2  Region
# 4            903              NaN              NaN            2  Region
#
#    Parent code  ...  \
# 0  Parent code  ...
# 1         1840  ...
# 2         1840  ...
# 3         1840  ...
# 4         1840  ...
#
# ...

# %%
Reg = Reg[1:]

# %%
Reg.head()
# Out:
#   Index    Variant Region, subregion, country or area * Notes Location code  \
# 1  1589  Estimates                               AFRICA   NaN           903
# 2  1590  Estimates                               AFRICA   NaN           903
# 3  1591  Estimates                               AFRICA   NaN           903
# 4  1592  Estimates                               AFRICA   NaN           903
# 5  1593  Estimates                               AFRICA   NaN           903
#
#   ISO3 Alpha-code ISO2 Alpha-code SDMX code**    Type Parent code  ...  \
# 1             NaN             NaN           2  Region        1840  ...
# 2             NaN             NaN           2  Region        1840  ...
# 3             NaN             NaN           2  Region        1840  ...
# 4             NaN             NaN           2  Region        1840  ...
# 5             NaN             NaN           2  Region        1840  ...
#
# ...

# %%
Reg = Reg.rename(columns={"Region, subregion, country or area *":"Region"})

# %%
Reg.head()
# Out:
#   Index    Variant  Region Notes Location code ISO3 Alpha-code  \
# 1  1589  Estimates  AFRICA   NaN           903             NaN
# 2  1590  Estimates  AFRICA   NaN           903             NaN
# 3  1591  Estimates  AFRICA   NaN           903             NaN
# 4  1592  Estimates  AFRICA   NaN           903             NaN
# 5  1593  Estimates  AFRICA   NaN           903             NaN
#
#   ISO2 Alpha-code SDMX code**    Type Parent code  ...  \
# 1             NaN           2  Region        1840  ...
# 2             NaN           2  Region        1840  ...
# 3             NaN           2  Region        1840  ...
# 4             NaN           2  Region        1840  ...
# 5             NaN           2  Region        1840  ...
#
#   Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)  \
# 1                                            676.242
# 2                                            673.073
# 3                                            667.352
# ...

# %%
Reg.Region.unique()
# Out:
# array(['AFRICA', 'ASIA', 'EUROPE', 'LATIN AMERICA AND THE CARIBBEAN',
#        'NORTHERN AMERICA', 'OCEANIA'], dtype=object)

# %%
Reg.iloc[:5,10:20]
# Out:
#    Year Total Population, as of 1 January (thousands)  \
# 1  1950                                    225120.311
# 2  1951                                    229978.205
# 3  1952                                    234989.784
# 4  1953                                    240182.336
# 5  1954                                    245492.559
#
#   Total Population, as of 1 July (thousands)  \
# 1                                 227549.258
# 2                                 232483.995
# 3                                  237586.06
# 4                                 242837.448
# 5                                 248244.771
#
#   Male Population, as of 1 July (thousands)  \
# 1                                113474.172
# 2                                115915.005
# 3                                118442.586
# 4                                121050.757
# 5                                123736.856
#
#   Female Population, as of 1 July (thousands)  \
# ...

# %%
Reg.iloc[:5,20:30]
# Out:
#   Population Change (thousands) Population Growth Rate (percentage)  \
# 1                      4857.894                               2.135
# 2                      5011.579                               2.156
# 3                      5192.552                               2.186
# 4                      5310.223                               2.187
# 5                      5504.423                               2.217
#
#   Population Annual Doubling Time (years) Births (thousands)  \
# 1                                  32.466          10949.117
# 2                                   32.15          11200.481
# 3                                  31.708          11448.324
# 4                                  31.694          11708.347
# 5                                  31.265          11941.297
#
#   Births by women aged 15 to 19 (thousands)  \
# 1                                  1682.377
# 2                                  1713.871
# 3                                  1740.078
# ...

# %%
Reg.iloc[:5,30:40]
# Out:
#   Total Deaths (thousands) Male Deaths (thousands) Female Deaths (thousands)  \
# 1                 6062.986                3152.087                  2910.899
# 2                 6132.451                3187.351                    2945.1
# 3                 6154.863                 3199.46                  2955.403
# 4                 6188.063                3216.657                  2971.406
# 5                 6233.523                 3252.43                  2981.093
#
#   Crude Death Rate (deaths per 1,000 population)  \
# 1                                         26.636
# 2                                          26.37
# 3                                         25.896
# 4                                         25.467
# 5                                         25.096
#
#   Life Expectancy at Birth, both sexes (years)  \
# 1                                       37.624
# 2                                       37.931
# 3                                       38.443
# ...

# %%
Reg.iloc[:5,40:50]
# Out:
#   Life Expectancy at Age 65, both sexes (years)  \
# 1                                        10.658
# 2                                        10.675
# 3                                        10.737
# 4                                        10.797
# 5                                        10.842
#
#   Male Life Expectancy at Age 65 (years)  \
# 1                                 10.353
# 2                                 10.354
# 3                                 10.409
# 4                                 10.461
# 5                                  10.48
#
#   Female Life Expectancy at Age 65 (years)  \
# 1                                   10.929
# 2                                    10.96
# 3                                   11.029
# 4                                   11.096
# 5                                   11.164
#
#   Life Expectancy at Age 80, both sexes (years)  \
# 1                                         4.701
# 2                                         4.706
# ...

# %%
Reg.iloc[:5,50:60]
# Out:
#   Under-Five Mortality (deaths under age 5 per 1,000 live births)  \
# 1                                            323.904
# 2                                            319.432
# 3                                            313.062
# 4                                            306.924
# 5                                            300.897
#
#   Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births)  \
# 1                                            500.908
# 2                                            496.578
# 3                                            489.666
# 4                                            483.243
# 5                                            478.505
#
#   Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births)  \
# 1                                            513.254
# 2                                            508.975
# 3                                            502.255
# ...

# %%
import pandas as pd

# %%
import requests
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/07-21-2022.csv'
res = requests.get(url, allow_redirects=True)
with open('COVID_JHU.csv','wb') as file:
    file.write(res.content)
JHU = pd.read_csv('COVID_JHU.csv')

# %%
JHU
# Out:
#       FIPS Admin2 Province_State        Country_Region          Last_Update  \
# 0      NaN    NaN            NaN           Afghanistan  2022-07-22 04:21:15
# 1      NaN    NaN            NaN               Albania  2022-07-21 23:21:03
# 2      NaN    NaN            NaN               Algeria  2022-07-22 04:21:15
# 3      NaN    NaN            NaN               Andorra  2022-07-22 04:21:15
# 4      NaN    NaN            NaN                Angola  2022-07-22 04:21:15
# ...    ...    ...            ...                   ...                  ...
# 4007   NaN    NaN            NaN    West Bank and Gaza  2022-07-22 04:21:15
# 4008   NaN    NaN            NaN  Winter Olympics 2022  2022-07-22 04:21:15
# 4009   NaN    NaN            NaN                 Yemen  2022-07-22 04:21:15
# 4010   NaN    NaN            NaN                Zambia  2022-07-22 04:21:15
# 4011   NaN    NaN            NaN              Zimbabwe  2022-07-22 04:21:15
#
# ...

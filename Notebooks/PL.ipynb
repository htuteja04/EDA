# %%
import pandas as pd

# %%
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
players = pd.read_csv('../Datasets/PL/Players.csv')

# %%
players.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0         Rk           Player     Nation        Pos         Squad        Age
# 1          1       Max Aarons    eng ENG         DF  Norwich City         21
# 2          2        Che Adams    sct SCO         FW   Southampton         25
# 3          3  Rayan Aït Nouri     fr FRA         DF        Wolves         20
# 4          4  Kristoffer Ajer     no NOR         DF     Brentford         23
#
#   Unnamed: 6 Playing Time Playing Time.1 Playing Time.2  ... Expected.1  \
# 0       Born           MP         Starts            Min  ...       npxG
# 1       2000           34             32           2881  ...        0.7
# 2       1996           30             23           2039  ...        7.1
# 3       2001           23             20           1828  ...        0.7
# 4       1998           24             23           1995  ...        0.8
#
# ...

# %%
players.iloc[0].values
# Out:
# array(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP',
#        'Starts', 'Min', '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt',
#        'CrdY', 'CrdR', 'Gls', 'Ast', 'G+A', 'G-PK', 'G+A-PK', 'xG',
#        'npxG', 'xA', 'npxG+xA', 'xG', 'xA', 'xG+xA', 'npxG', 'npxG+xA',
#        'Matches', '-9999'], dtype=object)

# %%
players.columns = players.iloc[0].values

# %%
players.head()
# Out:
#    Rk           Player   Nation  Pos         Squad  Age  Born  MP  Starts  \
# 0  Rk           Player   Nation  Pos         Squad  Age  Born  MP  Starts
# 1   1       Max Aarons  eng ENG   DF  Norwich City   21  2000  34      32
# 2   2        Che Adams  sct SCO   FW   Southampton   25  1996  30      23
# 3   3  Rayan Aït Nouri   fr FRA   DF        Wolves   20  2001  23      20
# 4   4  Kristoffer Ajer   no NOR   DF     Brentford   23  1998  24      23
#
#     Min  ...  npxG   xA  npxG+xA    xG    xA  xG+xA  npxG  npxG+xA  Matches  \
# 0   Min  ...  npxG   xA  npxG+xA    xG    xA  xG+xA  npxG  npxG+xA  Matches
# 1  2881  ...   0.7  1.4      2.1  0.02  0.04   0.07  0.02     0.07  Matches
# 2  2039  ...   7.1  2.6      9.7  0.31  0.12   0.43  0.31     0.43  Matches
# 3  1828  ...   0.7  1.3      2.1  0.04  0.07   0.10  0.04     0.10  Matches
# 4  1995  ...   0.8  1.4      2.2  0.04  0.06   0.10  0.04     0.10  Matches
#
#       -9999
# 0     -9999
# 1  774cf58b
# 2  f2bf1b0f
# ...

# %%
players = players.iloc[1:]

# %%
players.index = players['Rk']

# %%
players.drop('Rk',axis=1,inplace=True)

# %%
players.head()
# Out:
#              Player   Nation Pos            Squad Age  Born  MP Starts   Min  \
# Rk
# 1        Max Aarons  eng ENG  DF     Norwich City  21  2000  34     32  2881
# 2         Che Adams  sct SCO  FW      Southampton  25  1996  30     23  2039
# 3   Rayan Aït Nouri   fr FRA  DF           Wolves  20  2001  23     20  1828
# 4   Kristoffer Ajer   no NOR  DF        Brentford  23  1998  24     23  1995
# 5        Nathan Aké   nl NED  DF  Manchester City  26  1995  14     10   923
#
#      90s  ... npxG   xA npxG+xA    xG    xA xG+xA  npxG npxG+xA  Matches  \
# Rk        ...
# 1   32.0  ...  0.7  1.4     2.1  0.02  0.04  0.07  0.02    0.07  Matches
# 2   22.7  ...  7.1  2.6     9.7  0.31  0.12  0.43  0.31    0.43  Matches
# 3   20.3  ...  0.7  1.3     2.1  0.04  0.07  0.10  0.04    0.10  Matches
# 4   22.2  ...  0.8  1.4     2.2  0.04  0.06  0.10  0.04    0.10  Matches
# 5   10.3  ...  1.1  0.5     1.6  0.11  0.05  0.16  0.11    0.16  Matches
#
#        -9999
# Rk
# 1   774cf58b
# ...

# %%
players.iloc[:,-2:]
# Out:
#      Matches     -9999
# Rk
# 1    Matches  774cf58b
# 2    Matches  f2bf1b0f
# 3    Matches  9b398aea
# 4    Matches  a8c0acb7
# 5    Matches  eaeca114
# ..       ...       ...
# 542  Matches  2d5f03bf
# 543  Matches  51cf8561
# 544  Matches  6622454d
# 545  Matches  ce4246f5
# 546  Matches  79300479
#
# [546 rows x 2 columns]

# %%
players.drop(players.iloc[:,-2:], axis=1, inplace=True)

# %%
players.head()
# Out:
#              Player   Nation Pos            Squad Age  Born  MP Starts   Min  \
# Rk
# 1        Max Aarons  eng ENG  DF     Norwich City  21  2000  34     32  2881
# 2         Che Adams  sct SCO  FW      Southampton  25  1996  30     23  2039
# 3   Rayan Aït Nouri   fr FRA  DF           Wolves  20  2001  23     20  1828
# 4   Kristoffer Ajer   no NOR  DF        Brentford  23  1998  24     23  1995
# 5        Nathan Aké   nl NED  DF  Manchester City  26  1995  14     10   923
#
#      90s  ... G+A-PK   xG npxG   xA npxG+xA    xG    xA xG+xA  npxG npxG+xA
# Rk        ...
# 1   32.0  ...   0.06  0.7  0.7  1.4     2.1  0.02  0.04  0.07  0.02    0.07
# 2   22.7  ...   0.44  7.1  7.1  2.6     9.7  0.31  0.12  0.43  0.31    0.43
# 3   20.3  ...   0.15  0.7  0.7  1.3     2.1  0.04  0.07  0.10  0.04    0.10
# 4   22.2  ...   0.18  0.8  0.8  1.4     2.2  0.04  0.06  0.10  0.04    0.10
# 5   10.3  ...   0.20  1.1  1.1  0.5     1.6  0.11  0.05  0.16  0.11    0.16
#
# [5 rows x 31 columns]

# %%
players.Nation.unique()
# Out:
# array(['eng ENG', 'sct SCO', 'fr FRA', 'no NOR', 'nl NED', 'es ESP',
#        'br BRA', 'py PAR', 'co COL', 'gh GHA', 'dk DEN', 'jm JAM',
#        'ga GAB', 'at AUT', 'ci CIV', 'gd GRN', 'pl POL', 'ba BIH',
#        'dz ALG', 'uy URU', 'be BEL', 'is ISL', 'ml MLI', 'al ALB',
#        'ar ARG', 'ec ECU', 'wls WAL', 'pt POR', 'nir NIR', 'ie IRL',
#        'ao ANG', 'cz CZE', 'zm ZAM', 'ng NGA', 'sk SVK', 'se SWE',
#        'eg EGY', 'fi FIN', 'ir IRN', 'gr GRE', 'de GER', 'kr KOR',
#        'mx MEX', 'it ITA', 'tr TUR', 'cd COD', 'gn GUI', 'sn SEN',
#        'hr CRO', 'ma MAR', 'rs SRB', 'cm CMR', 'tn TUN', 'jp JPN',
#        'ua UKR', 'zw ZIM', 'us USA', 'xk KVX', 've VEN', 'ch SUI',
#        'cl CHI', 'bf BFA', 'nz NZL'], dtype=object)

# %%
idxs = players.Nation.str.index(' ')

# %%
players.Nation[0][4:]
# Out:
# 'ENG'

# %%
idxs
# Out:
# Rk
# 1      3
# 2      3
# 3      2
# 4      2
# 5      2
#       ..
# 542    2
# 543    2
# 544    2
# 545    2
# 546    2
# Name: Nation, Length: 546, dtype: int64

# %%
len(idxs)
# Out:
# 546

# %%
i=0
r=[]
while i<len(idxs):
    r.append(players.Nation[i][idxs[i]+1:])
    i+=1

# %%
r[:10]
# Out:
# ['ENG', 'SCO', 'FRA', 'NOR', 'NED', 'ENG', 'ESP', 'ENG', 'BRA', 'BRA']

# %%
players.Nation = r

# %%
players.head()
# Out:
#              Player Nation Pos            Squad Age  Born  MP Starts   Min  \
# Rk
# 1        Max Aarons    ENG  DF     Norwich City  21  2000  34     32  2881
# 2         Che Adams    SCO  FW      Southampton  25  1996  30     23  2039
# 3   Rayan Aït Nouri    FRA  DF           Wolves  20  2001  23     20  1828
# 4   Kristoffer Ajer    NOR  DF        Brentford  23  1998  24     23  1995
# 5        Nathan Aké    NED  DF  Manchester City  26  1995  14     10   923
#
#      90s  ... G+A-PK   xG npxG   xA npxG+xA    xG    xA xG+xA  npxG npxG+xA
# Rk        ...
# 1   32.0  ...   0.06  0.7  0.7  1.4     2.1  0.02  0.04  0.07  0.02    0.07
# 2   22.7  ...   0.44  7.1  7.1  2.6     9.7  0.31  0.12  0.43  0.31    0.43
# 3   20.3  ...   0.15  0.7  0.7  1.3     2.1  0.04  0.07  0.10  0.04    0.10
# 4   22.2  ...   0.18  0.8  0.8  1.4     2.2  0.04  0.06  0.10  0.04    0.10
# 5   10.3  ...   0.20  1.1  1.1  0.5     1.6  0.11  0.05  0.16  0.11    0.16
#
# [5 rows x 31 columns]

# %%
players.Pos.unique()
# Out:
# array(['DF', 'FW', 'FWDF', 'MF', 'GK', 'MFFW', 'FWMF', 'DFMF', 'MFDF',
#        'DFFW'], dtype=object)

# %%
players.Pos = players.Pos.replace({'FWDF':'FW/DF',
                                  'MFFW':'MF/FW',
                                  'FWMF':'FW/MF',
                                  'DFMF':'DF/MF',
                                  'MFDF':'MF/DF'})

# %%
players.Pos.unique()
# Out:
# array(['DF', 'FW', 'FW/DF', 'MF', 'GK', 'MF/FW', 'FW/MF', 'DF/MF',
#        'MF/DF', 'DFFW'], dtype=object)

# %%
players.Nation.value_counts()[:21]
# Out:
# ENG    199
# FRA     31
# ESP     30
# BRA     27
# POR     21
# NED     16
# SCO     16
# IRL     14
# DEN     14
# WAL     12
# GER     10
# BEL     10
# NGA      9
# ARG      8
# CIV      7
# SWE      7
# NOR      7
# POL      6
# GHA      6
# SEN      5
# COL      5
# Name: Nation, dtype: int64

# %%
players.Pos.value_counts()
# Out:
# DF       185
# MF       116
# FW        83
# FW/MF     59
# GK        42
# MF/FW     39
# MF/DF     11
# DF/MF      5
# DFFW       4
# FW/DF      2
# Name: Pos, dtype: int64

# %%
len(players.Nation.unique())
# Out:
# 63

# %%
players.Nation = players.Nation.replace({"GBR":"England",
                                        "SCO":"Scotland",
                                        "NED":"Netherlands",
                                        "DEN":"Denmark",
                                        "ALG":"Algeria",
                                        "URU":"Uruguay",
                                        "POR":"Portugal",
                                        "GER":"Germany",
                                        "IRL":"Ireland",
                                        "WAL":"Wales",
                                        "NOR":"Norway",
                                        "POL":"Poland",
                                        "SEN":"Senegal",
                                        "GHA":"Ghana",
                                        "NGA":"Nigeria",
                                        "ARG":"Argentina",
                                        "BEL":"Belgium",
                                        "FRA":"France",
                                        "ESP":"Spain",
                                        "SWE":"Sweden",
                                        "CIV":"Ivory Coast",
                                        "BRA":"Brazil",
                                        "COL":"Colombia"})

# %%
players.Nation
# Out:
# Rk
# 1              ENG
# 2         Scotland
# 3           France
# 4           Norway
# 5      Netherlands
#           ...
# 542        Germany
# 543            UKR
# 544            MAR
# 545         France
# 546         Norway
# Name: Nation, Length: 546, dtype: object

# %%
players
# Out:
#                    Player       Nation    Pos            Squad Age  Born  MP  \
# Rk
# 1              Max Aarons          ENG     DF     Norwich City  21  2000  34
# 2               Che Adams     Scotland     FW      Southampton  25  1996  30
# 3         Rayan Aït Nouri       France     DF           Wolves  20  2001  23
# 4         Kristoffer Ajer       Norway     DF        Brentford  23  1998  24
# 5              Nathan Aké  Netherlands     DF  Manchester City  26  1995  14
# ..                    ...          ...    ...              ...  ..   ...  ..
# 542  Christoph Zimmermann      Germany     DF     Norwich City  28  1993   3
# 543   Oleksandr Zinchenko          UKR     DF  Manchester City  24  1996  15
# 544          Hakim Ziyech          MAR  FW/MF          Chelsea  28  1993  23
# 545            Kurt Zouma       France     DF         West Ham  26  1994  24
# 546       Martin Ødegaard       Norway     MF          Arsenal  22  1998  36
#
# ...

# %%
players.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP', 'Starts',
#        'Min', '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR',
#        'Gls', 'Ast', 'G+A', 'G-PK', 'G+A-PK', 'xG', 'npxG', 'xA', 'npxG+xA',
#        'xG', 'xA', 'xG+xA', 'npxG', 'npxG+xA'],
#       dtype='object')

# %%
players = players.rename({"Squad":"Club",
                         "MP":"Matches played",
                         "Min":"Minutes played",
                         "90s":"Matches completed",
                         "Gls":"Goals",
                         "Ast":"Assists",
                         "CrdY":"Yellow cards",
                         "CrdR":"Red cards"},axis=1)

# %%
players.head()
# Out:
#              Player       Nation Pos             Club Age  Born  \
# Rk
# 1        Max Aarons          ENG  DF     Norwich City  21  2000
# 2         Che Adams     Scotland  FW      Southampton  25  1996
# 3   Rayan Aït Nouri       France  DF           Wolves  20  2001
# 4   Kristoffer Ajer       Norway  DF        Brentford  23  1998
# 5        Nathan Aké  Netherlands  DF  Manchester City  26  1995
#
#    Matches played Starts Minutes played Matches completed  ... G+A-PK   xG  \
# Rk                                                         ...
# 1              34     32           2881              32.0  ...   0.06  0.7
# 2              30     23           2039              22.7  ...   0.44  7.1
# 3              23     20           1828              20.3  ...   0.15  0.7
# 4              24     23           1995              22.2  ...   0.18  0.8
# 5              14     10            923              10.3  ...   0.20  1.1
#
#    npxG   xA npxG+xA    xG    xA xG+xA  npxG npxG+xA
# Rk
# ...

# %%
players = players.drop(['G-PK', 'PK', 'PKatt'],axis=1)

# %%
players.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Club', 'Age', 'Born', 'Matches played',
#        'Starts', 'Minutes played', 'Matches completed', 'Goals', 'Assists',
#        'Yellow cards', 'Red cards', 'Goals', 'Assists', 'G+A', 'G+A-PK', 'xG',
#        'npxG', 'xA', 'npxG+xA', 'xG', 'xA', 'xG+xA', 'npxG', 'npxG+xA'],
#       dtype='object')

# %%
players = players.drop(['G+A-PK', 'G+A'],axis=1)

# %%
players.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Club', 'Age', 'Born', 'Matches played',
#        'Starts', 'Minutes played', 'Matches completed', 'Goals', 'Assists',
#        'Yellow cards', 'Red cards', 'Goals', 'Assists', 'xG', 'npxG', 'xA',
#        'npxG+xA', 'xG', 'xA', 'xG+xA', 'npxG', 'npxG+xA'],
#       dtype='object')

# %%
players.head()
# Out:
#              Player       Nation Pos             Club Age  Born  \
# Rk
# 1        Max Aarons          ENG  DF     Norwich City  21  2000
# 2         Che Adams     Scotland  FW      Southampton  25  1996
# 3   Rayan Aït Nouri       France  DF           Wolves  20  2001
# 4   Kristoffer Ajer       Norway  DF        Brentford  23  1998
# 5        Nathan Aké  Netherlands  DF  Manchester City  26  1995
#
#    Matches played Starts Minutes played Matches completed  ... Assists   xG  \
# Rk                                                         ...
# 1              34     32           2881              32.0  ...    0.06  0.7
# 2              30     23           2039              22.7  ...    0.13  7.1
# 3              23     20           1828              20.3  ...    0.10  0.7
# 4              24     23           1995              22.2  ...    0.14  0.8
# 5              14     10            923              10.3  ...    0.00  1.1
#
#    npxG   xA npxG+xA    xG    xA xG+xA  npxG npxG+xA
# ...

# %%
players = players.iloc[:, :-5]

# %%
players.shape
# Out:
# (546, 20)

# %%
players.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Club', 'Age', 'Born', 'Matches played',
#        'Starts', 'Minutes played', 'Matches completed', 'Goals', 'Assists',
#        'Yellow cards', 'Red cards', 'Goals', 'Assists', 'xG', 'npxG', 'xA',
#        'npxG+xA'],
#       dtype='object')

# %%
players.columns = ['Player', 'Nation', 'Pos', 'Club', 'Age', 'Born', 'Matches played',
       'Starts', 'Minutes played', 'Matches completed', 'Goals', 'Assists',
       'Yellow cards', 'Red cards', 'Goals/90', 'Assists/90', 'xG', 'npxG', 'xA',
       'npxG+xA']

# %%
players.shape
# Out:
# (546, 20)

# %%
players.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Club', 'Age', 'Born', 'Matches played',
#        'Starts', 'Minutes played', 'Matches completed', 'Goals', 'Assists',
#        'Yellow cards', 'Red cards', 'Goals/90', 'Assists/90', 'xG', 'npxG',
#        'xA', 'npxG+xA'],
#       dtype='object')

# %%
players.tail()
# Out:
#                    Player   Nation    Pos             Club Age  Born  \
# Rk
# 542  Christoph Zimmermann  Germany     DF     Norwich City  28  1993
# 543   Oleksandr Zinchenko      UKR     DF  Manchester City  24  1996
# 544          Hakim Ziyech      MAR  FW/MF          Chelsea  28  1993
# 545            Kurt Zouma   France     DF         West Ham  26  1994
# 546       Martin Ødegaard   Norway     MF          Arsenal  22  1998
#
#     Matches played Starts Minutes played Matches completed Goals Assists  \
# Rk
# 542              3      2            157               1.7     0       0
# 543             15     10           1047              11.6     0       4
# 544             23     14           1319              14.7     4       3
# 545             24     24           2078              23.1     1       0
# 546             36     32           2785              30.9     7       4
#
#     Yellow cards Red cards Goals/90 Assists/90   xG npxG   xA npxG+xA
# Rk
# ...

# %%
players.dtypes
# Out:
# Player               object
# Nation               object
# Pos                  object
# Club                 object
# Age                  object
# Born                 object
# Matches played       object
# Starts               object
# Minutes played       object
# Matches completed    object
# Goals                object
# Assists              object
# Yellow cards         object
# Red cards            object
# Goals/90             object
# Assists/90           object
# xG                   object
# npxG                 object
# xA                   object
# npxG+xA              object
# dtype: object

# %%
players.Goals = players.Goals.astype(int)
players.Assists = players.Assists.astype(int)
players.xG = players.xG.astype(float)
players.xA = players.xA.astype(float)
players.npxG = players.npxG.astype(float)
players['Goals/90'] = players['Goals/90'].astype(float)
players['Assists/90'] = players['Assists/90'].astype(float)
players.Age = players.Age.astype(int)

# %%
players.dtypes
# Out:
# Player                object
# Nation                object
# Pos                   object
# Club                  object
# Age                    int32
# Born                  object
# Matches played        object
# Starts                object
# Minutes played        object
# Matches completed     object
# Goals                  int32
# Assists                int32
# Yellow cards          object
# Red cards             object
# Goals/90             float64
# Assists/90           float64
# xG                   float64
# npxG                 float64
# xA                   float64
# npxG+xA               object
# dtype: object

# %%
players.groupby('Player').Goals.sum().sort_values(ascending=False)
# Out:
# Player
# Mohamed Salah         23
# Son Heung-min         23
# Cristiano Ronaldo     18
# Harry Kane            17
# Sadio Mané            16
#                       ..
# Japhet Tanganga        0
# Jannik Vestergaard     0
# Jamie Shackleton       0
# James Milner           0
# Łukasz Fabiański       0
# Name: Goals, Length: 537, dtype: int32

# %%
players.groupby('Player').xG.sum().sort_values(ascending=False)
# Out:
# Player
# Mohamed Salah          21.8
# Harry Kane             20.1
# Sadio Mané             16.7
# Cristiano Ronaldo      16.5
# Son Heung-min          16.4
#                        ...
# Fraser Forster          0.0
# Francisco Sierralta     0.0
# Phil Jones              0.0
# Finley Stevens          0.0
# Łukasz Fabiański        0.0
# Name: xG, Length: 537, dtype: float64

# %%
players.groupby('Player').Assists.sum().sort_values(ascending=False)
# Out:
# Player
# Mohamed Salah             13
# Trent Alexander-Arnold    12
# Andrew Robertson          10
# Jarrod Bowen              10
# Harvey Barnes             10
#                           ..
# James Justin               0
# Jamal Lewis                0
# Jamaal Lascelles           0
# Jakob Sørensen             0
# Łukasz Fabiański           0
# Name: Assists, Length: 537, dtype: int32

# %%
players.groupby('Club').Age.agg('mean').sort_values()
# Out:
# Club
# Leeds United       23.310345
# Norwich City       23.964286
# Brentford          24.206897
# Tottenham          24.480000
# Arsenal            24.518519
# Brighton           24.730769
# Aston Villa        24.967742
# Manchester City    25.038462
# Wolves             25.038462
# Everton            25.151515
# Liverpool          25.333333
# Leicester City     25.428571
# Manchester Utd     25.620690
# Southampton        25.880000
# Chelsea            26.000000
# Crystal Palace     26.208333
# West Ham           26.400000
# Watford            27.233333
# Newcastle Utd      27.310345
# Burnley            28.956522
# Name: Age, dtype: float64

# %%
players.groupby('Club').Goals.agg(sum).sort_values(ascending=False)
# Out:
# Club
# Manchester City    96
# Liverpool          94
# Chelsea            75
# Tottenham          63
# Leicester City     62
# Arsenal            60
# West Ham           58
# Manchester Utd     56
# Crystal Palace     50
# Aston Villa        50
# Brentford          46
# Everton            42
# Leeds United       42
# Newcastle Utd      41
# Southampton        41
# Brighton           40
# Wolves             35
# Watford            33
# Burnley            32
# Norwich City       21
# Name: Goals, dtype: int32

# %%
players.groupby('Club').xG.agg(sum).sort_values(ascending=False)
# Out:
# Club
# Liverpool          91.1
# Manchester City    90.9
# Chelsea            69.0
# Tottenham          66.0
# Arsenal            61.4
# Manchester Utd     55.1
# Leicester City     51.7
# West Ham           51.0
# Brentford          48.3
# Leeds United       48.1
# Southampton        47.6
# Crystal Palace     46.9
# Brighton           46.7
# Aston Villa        44.7
# Everton            43.4
# Newcastle Utd      41.3
# Burnley            39.8
# Watford            39.2
# Wolves             36.7
# Norwich City       34.2
# Name: xG, dtype: float64

# %%
players.groupby('Club').npxG.agg(sum).sort_values(ascending=False)
# Out:
# Club
# Liverpool          84.8
# Manchester City    84.0
# Tottenham          62.2
# Chelsea            62.2
# Arsenal            55.2
# Manchester Utd     51.3
# Leicester City     50.2
# West Ham           46.5
# Southampton        44.5
# Leeds United       44.3
# Brentford          43.8
# Aston Villa        42.4
# Brighton           41.4
# Crystal Palace     40.7
# Newcastle Utd      39.0
# Burnley            38.2
# Everton            38.1
# Watford            37.7
# Wolves             36.2
# Norwich City       31.9
# Name: npxG, dtype: float64

# %%
players.groupby(['Club', 'Player'],as_index=False)['Goals'].agg(max).sort_values(by='Goals',ascending=False)[:21]
# Out:
#                 Club             Player  Goals
# 293        Liverpool      Mohamed Salah     23
# 462        Tottenham      Son Heung-min     23
# 335   Manchester Utd  Cristiano Ronaldo     18
# 450        Tottenham         Harry Kane     17
# 297        Liverpool         Sadio Mané     16
# 281        Liverpool         Diogo Jota     15
# 257   Leicester City        Jamie Vardy     15
# 317  Manchester City    Kevin De Bruyne     15
# 184   Crystal Palace      Wilfried Zaha     14
# 323  Manchester City    Raheem Sterling     13
# 507         West Ham       Jarrod Bowen     12
# 256   Leicester City     James Maddison     12
# 67         Brentford         Ivan Toney     12
# 411     Norwich City        Teemu Pukki     11
# 151          Chelsea        Mason Mount     11
# 324  Manchester City       Riyad Mahrez     11
# 51       Aston Villa      Ollie Watkins     11
# 241     Leeds United           Raphinha     11
# 6            Arsenal        Bukayo Saka     11
# ...

# %%
players.to_csv('../Datasets/PL/players-mod.csv')

# %% [markdown]
# ![Screenshot%20%289%29.png](attachment:Screenshot%20%289%29.png)

# %% [markdown]
# ![Screenshot%20%2810%29.png](attachment:Screenshot%20%2810%29.png)

# %% [markdown]
# ![Screenshot%20%2811%29.png](attachment:Screenshot%20%2811%29.png)

# %% [markdown]
# ![Screenshot%20%2812%29.png](attachment:Screenshot%20%2812%29.png)

# %% [markdown]
# ![Screenshot%20%2813%29.png](attachment:Screenshot%20%2813%29.png)

# %% [markdown]
# ![Screenshot%20%2814%29.png](attachment:Screenshot%20%2814%29.png)

# %% [markdown]
# ![Screenshot%20%2815%29.png](attachment:Screenshot%20%2815%29.png)

# %% [markdown]
# ![Screenshot%20%2816%29.png](attachment:Screenshot%20%2816%29.png)

# %%
Teams = pd.read_csv('../Datasets/PL/Teams.csv')

# %%
Teams = Teams.set_index('Rk')

# %%
Teams = Teams.drop('Notes',axis=1)

# %%
Teams
# Out:
#               Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# Rk
# 1   Manchester City  38  29   6   3  99  26  73   93    2.45  89.0  27.2
# 2         Liverpool  38  28   8   2  94  26  68   92    2.42  89.2  34.3
# 3           Chelsea  38  21  11   6  76  33  43   74    1.95  67.2  36.0
# 4         Tottenham  38  22   5  11  69  40  29   71    1.87  65.1  39.4
# 5           Arsenal  38  22   3  13  61  48  13   69    1.82  59.9  47.1
# 6    Manchester Utd  38  16  10  12  57  57   0   58    1.53  54.8  54.5
# 7          West Ham  38  16   8  14  60  51   9   56    1.47  49.9  51.0
# 8    Leicester City  38  14  10  14  62  59   3   52    1.37  50.8  61.0
# 9          Brighton  38  12  15  11  42  44  -2   51    1.34  46.0  45.6
# 10           Wolves  38  15   6  17  38  43  -5   51    1.34  35.9  60.3
# 11    Newcastle Utd  38  13  10  15  44  62 -18   49    1.29  40.3  55.4
# 12   Crystal Palace  38  11  15  12  50  46   4   48    1.26  46.4  41.0
# ...

# %%
Passing = pd.read_csv('../Datasets/PL/Passing.csv')

# %%
Passing
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2  Total Total.1 Total.2  Total.3  \
# 0             Squad       # Pl        90s    Cmp     Att    Cmp%  TotDist
# 1           Arsenal         27       38.0  16110   19512    82.6   300732
# 2       Aston Villa         31       38.0  12521   16026    78.1   244814
# 3         Brentford         29       38.0  11551   15894    72.7   234064
# 4          Brighton         26       38.0  16342   20297    80.5   319634
# 5           Burnley         23       38.0   9508   13895    68.4   199165
# 6           Chelsea         26       38.0  20878   24294    85.9   382347
# 7    Crystal Palace         24       38.0  14780   18643    79.3   292426
# 8           Everton         33       38.0  10325   14297    72.2   206029
# 9      Leeds United         29       38.0  13830   17836    77.5   267921
# 10   Leicester City         28       38.0  15911   19634    81.0   301146
# 11        Liverpool         27       38.0  20856   24964    83.5   412739
# ...

# %%
Passing.iloc[0].values
# Out:
# array(['Squad', '# Pl', '90s', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist',
#        'Cmp', 'Att', 'Cmp%', 'Cmp', 'Att', 'Cmp%', 'Cmp', 'Att', 'Cmp%',
#        'Ast', 'xA', 'A-xA', 'KP', '1/3', 'PPA', 'CrsPA', 'Prog'],
#       dtype=object)

# %%
Passing.columns = ['Squad', '# Pl', '90s', 'Total_Cmp', 'Total_Att', 'Total_Cmp%', 'Total_Dist', 'Total_PrgDist',
       'Short_Cmp', 'Short_Att', 'Short_Cmp%', 'Medium_Cmp', 'Medium_Att', 'Medium_Cmp%', 'Long_Cmp', 'Long_Att', 'Long_Cmp%',
       'Assists', 'xA', 'A-xA', 'Key_passes', 'Final_third_passes', 'Passes_in_PA', 'Crosses_in_PA', 'Progressive_passes']

# %%
Passing
# Out:
#               Squad  # Pl   90s Total_Cmp Total_Att Total_Cmp% Total_Dist  \
# 0             Squad  # Pl   90s       Cmp       Att       Cmp%    TotDist
# 1           Arsenal    27  38.0     16110     19512       82.6     300732
# 2       Aston Villa    31  38.0     12521     16026       78.1     244814
# 3         Brentford    29  38.0     11551     15894       72.7     234064
# 4          Brighton    26  38.0     16342     20297       80.5     319634
# 5           Burnley    23  38.0      9508     13895       68.4     199165
# 6           Chelsea    26  38.0     20878     24294       85.9     382347
# 7    Crystal Palace    24  38.0     14780     18643       79.3     292426
# 8           Everton    33  38.0     10325     14297       72.2     206029
# 9      Leeds United    29  38.0     13830     17836       77.5     267921
# 10   Leicester City    28  38.0     15911     19634       81.0     301146
# 11        Liverpool    27  38.0     20856     24964       83.5     412739
# ...

# %%
Passing = Passing.iloc[1:]

# %%
Passing
# Out:
#               Squad # Pl   90s Total_Cmp Total_Att Total_Cmp% Total_Dist  \
# 1           Arsenal   27  38.0     16110     19512       82.6     300732
# 2       Aston Villa   31  38.0     12521     16026       78.1     244814
# 3         Brentford   29  38.0     11551     15894       72.7     234064
# 4          Brighton   26  38.0     16342     20297       80.5     319634
# 5           Burnley   23  38.0      9508     13895       68.4     199165
# 6           Chelsea   26  38.0     20878     24294       85.9     382347
# 7    Crystal Palace   24  38.0     14780     18643       79.3     292426
# 8           Everton   33  38.0     10325     14297       72.2     206029
# 9      Leeds United   29  38.0     13830     17836       77.5     267921
# 10   Leicester City   28  38.0     15911     19634       81.0     301146
# 11        Liverpool   27  38.0     20856     24964       83.5     412739
# 12  Manchester City   26  38.0     24032     27275       88.1     456456
# ...

# %%
Passing = Passing.drop('# Pl',axis=1)

# %%
Passing = Passing.drop('90s',axis=1)

# %%
Passing
# Out:
#               Squad Total_Cmp Total_Att Total_Cmp% Total_Dist Total_PrgDist  \
# 1           Arsenal     16110     19512       82.6     300732         87839
# 2       Aston Villa     12521     16026       78.1     244814         86229
# 3         Brentford     11551     15894       72.7     234064         86823
# 4          Brighton     16342     20297       80.5     319634         96944
# 5           Burnley      9508     13895       68.4     199165         82436
# 6           Chelsea     20878     24294       85.9     382347        114543
# 7    Crystal Palace     14780     18643       79.3     292426         94182
# 8           Everton     10325     14297       72.2     206029         78513
# 9      Leeds United     13830     17836       77.5     267921         90174
# 10   Leicester City     15911     19634       81.0     301146         95451
# 11        Liverpool     20856     24964       83.5     412739        130477
# ...

# %%
Passing.dtypes
# Out:
# Squad                 object
# Total_Cmp             object
# Total_Att             object
# Total_Cmp%            object
# Total_Dist            object
# Total_PrgDist         object
# Short_Cmp             object
# Short_Att             object
# Short_Cmp%            object
# Medium_Cmp            object
# Medium_Att            object
# Medium_Cmp%           object
# Long_Cmp              object
# Long_Att              object
# Long_Cmp%             object
# Assists               object
# xA                    object
# A-xA                  object
# Key_passes            object
# Final_third_passes    object
# Passes_in_PA          object
# Crosses_in_PA         object
# Progressive_passes    object
# dtype: object

# %%
Passing_a = Passing.drop('Squad',axis=1)

# %%
Passing_a[Passing_a.columns] = Passing_a[Passing_a.columns].astype(float)

# %%
Passing_a.dtypes
# Out:
# Total_Cmp             float64
# Total_Att             float64
# Total_Cmp%            float64
# Total_Dist            float64
# Total_PrgDist         float64
# Short_Cmp             float64
# Short_Att             float64
# Short_Cmp%            float64
# Medium_Cmp            float64
# Medium_Att            float64
# Medium_Cmp%           float64
# Long_Cmp              float64
# Long_Att              float64
# Long_Cmp%             float64
# Assists               float64
# xA                    float64
# A-xA                  float64
# Key_passes            float64
# Final_third_passes    float64
# Passes_in_PA          float64
# Crosses_in_PA         float64
# Progressive_passes    float64
# dtype: object

# %%
Passing_a['Club'] = Passing['Squad']

# %%
Passing_a
# Out:
#     Total_Cmp  Total_Att  Total_Cmp%  Total_Dist  Total_PrgDist  Short_Cmp  \
# 1     16110.0    19512.0        82.6    300732.0        87839.0     6886.0
# 2     12521.0    16026.0        78.1    244814.0        86229.0     5111.0
# 3     11551.0    15894.0        72.7    234064.0        86823.0     4443.0
# 4     16342.0    20297.0        80.5    319634.0        96944.0     6439.0
# 5      9508.0    13895.0        68.4    199165.0        82436.0     4020.0
# 6     20878.0    24294.0        85.9    382347.0       114543.0     9010.0
# 7     14780.0    18643.0        79.3    292426.0        94182.0     5669.0
# 8     10325.0    14297.0        72.2    206029.0        78513.0     4314.0
# 9     13830.0    17836.0        77.5    267921.0        90174.0     5535.0
# 10    15911.0    19634.0        81.0    301146.0        95451.0     6529.0
# 11    20856.0    24964.0        83.5    412739.0       130477.0     7998.0
# ...

# %%
Passing = Passing_a

# %%
Passing
# Out:
#     Total_Cmp  Total_Att  Total_Cmp%  Total_Dist  Total_PrgDist  Short_Cmp  \
# 1     16110.0    19512.0        82.6    300732.0        87839.0     6886.0
# 2     12521.0    16026.0        78.1    244814.0        86229.0     5111.0
# 3     11551.0    15894.0        72.7    234064.0        86823.0     4443.0
# 4     16342.0    20297.0        80.5    319634.0        96944.0     6439.0
# 5      9508.0    13895.0        68.4    199165.0        82436.0     4020.0
# 6     20878.0    24294.0        85.9    382347.0       114543.0     9010.0
# 7     14780.0    18643.0        79.3    292426.0        94182.0     5669.0
# 8     10325.0    14297.0        72.2    206029.0        78513.0     4314.0
# 9     13830.0    17836.0        77.5    267921.0        90174.0     5535.0
# 10    15911.0    19634.0        81.0    301146.0        95451.0     6529.0
# 11    20856.0    24964.0        83.5    412739.0       130477.0     7998.0
# ...

# %%
Passing.to_csv('../Datasets/PL/Passing-mod.csv')

# %% [markdown]
# ![Screenshot%20%2818%29.png](attachment:Screenshot%20%2818%29.png)

# %% [markdown]
# ![Screenshot%20%2819%29.png](attachment:Screenshot%20%2819%29.png)

# %% [markdown]
# ![Screenshot%20%2820%29.png](attachment:Screenshot%20%2820%29.png)

# %% [markdown]
# ![Screenshot%20%2821%29.png](attachment:Screenshot%20%2821%29.png)

# %% [markdown]
# ![Screenshot%20%2822%29.png](attachment:Screenshot%20%2822%29.png)

# %% [markdown]
# ![Screenshot%20%2823%29.png](attachment:Screenshot%20%2823%29.png)

# %% [markdown]
# ![Screenshot%20%2827%29.png](attachment:Screenshot%20%2827%29.png)

# %% [markdown]
# ![Screenshot%20%2824%29.png](attachment:Screenshot%20%2824%29.png)

# %%
Shooting = pd.read_csv('../Datasets/PL/Shooting.csv')

# %%
Shooting
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Standard Standard.1 Standard.2  \
# 0             Squad       # Pl        90s      Gls         Sh        SoT
# 1           Arsenal         27       38.0       60        580        185
# 2       Aston Villa         31       38.0       50        461        159
# 3         Brentford         29       38.0       46        441        139
# 4          Brighton         26       38.0       40        483        140
# 5           Burnley         23       38.0       32        406        117
# 6           Chelsea         26       38.0       75        585        199
# 7    Crystal Palace         24       38.0       50        404        141
# 8           Everton         33       38.0       42        431        127
# 9      Leeds United         29       38.0       42        485        142
# 10   Leicester City         28       38.0       62        436        163
# 11        Liverpool         27       38.0       94        722        237
# ...

# %%
Shooting.iloc[0].values
# Out:
# array(['Squad', '# Pl', '90s', 'Gls', 'Sh', 'SoT', 'SoT%', 'Sh/90',
#        'SoT/90', 'G/Sh', 'G/SoT', 'Dist', 'FK', 'PK', 'PKatt', 'xG',
#        'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG'], dtype=object)

# %%
Shooting.columns = ['Club', '# Pl', '90s', 'Goals', 'Shots', 'Shots-on-Target', 'SoT%', 'Shots-per-90',
       'Shots-on-Target-per-90', 'Goals-per-Shots', 'Goals-per-SoT', 'Distaance-from-goal', 'Free-kicks', 'Pens', 'PKatt', 'Expected-goals',
       'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG']

# %%
Shooting
# Out:
#                Club  # Pl   90s Goals Shots Shots-on-Target  SoT%  \
# 0             Squad  # Pl   90s   Gls    Sh             SoT  SoT%
# 1           Arsenal    27  38.0    60   580             185  31.9
# 2       Aston Villa    31  38.0    50   461             159  34.5
# 3         Brentford    29  38.0    46   441             139  31.5
# 4          Brighton    26  38.0    40   483             140  29.0
# 5           Burnley    23  38.0    32   406             117  28.8
# 6           Chelsea    26  38.0    75   585             199  34.0
# 7    Crystal Palace    24  38.0    50   404             141  34.9
# 8           Everton    33  38.0    42   431             127  29.5
# 9      Leeds United    29  38.0    42   485             142  29.3
# 10   Leicester City    28  38.0    62   436             163  37.4
# 11        Liverpool    27  38.0    94   722             237  32.8
# 12  Manchester City    26  38.0    96   704             239  33.9
# ...

# %%
Shooting = Shooting.iloc[1:]

# %%
Shooting
# Out:
#                Club # Pl   90s Goals Shots Shots-on-Target  SoT% Shots-per-90  \
# 1           Arsenal   27  38.0    60   580             185  31.9        15.26
# 2       Aston Villa   31  38.0    50   461             159  34.5        12.13
# 3         Brentford   29  38.0    46   441             139  31.5        11.61
# 4          Brighton   26  38.0    40   483             140  29.0        12.71
# 5           Burnley   23  38.0    32   406             117  28.8        10.68
# 6           Chelsea   26  38.0    75   585             199  34.0        15.39
# 7    Crystal Palace   24  38.0    50   404             141  34.9        10.63
# 8           Everton   33  38.0    42   431             127  29.5        11.34
# 9      Leeds United   29  38.0    42   485             142  29.3        12.76
# 10   Leicester City   28  38.0    62   436             163  37.4        11.47
# 11        Liverpool   27  38.0    94   722             237  32.8        19.00
# ...

# %%
Shooting.iloc[:,1:3]
# Out:
#    # Pl   90s
# 1    27  38.0
# 2    31  38.0
# 3    29  38.0
# 4    26  38.0
# 5    23  38.0
# 6    26  38.0
# 7    24  38.0
# 8    33  38.0
# 9    29  38.0
# 10   28  38.0
# 11   27  38.0
# 12   26  38.0
# 13   29  38.0
# 14   29  38.0
# 15   28  38.0
# 16   25  38.0
# 17   25  38.0
# 18   30  38.0
# 19   25  38.0
# 20   26  38.0

# %%
Shooting = Shooting.drop(Shooting.iloc[:,1:3],axis=1)

# %%
Shooting
# Out:
#                Club Goals Shots Shots-on-Target  SoT% Shots-per-90  \
# 1           Arsenal    60   580             185  31.9        15.26
# 2       Aston Villa    50   461             159  34.5        12.13
# 3         Brentford    46   441             139  31.5        11.61
# 4          Brighton    40   483             140  29.0        12.71
# 5           Burnley    32   406             117  28.8        10.68
# 6           Chelsea    75   585             199  34.0        15.39
# 7    Crystal Palace    50   404             141  34.9        10.63
# 8           Everton    42   431             127  29.5        11.34
# 9      Leeds United    42   485             142  29.3        12.76
# 10   Leicester City    62   436             163  37.4        11.47
# 11        Liverpool    94   722             237  32.8        19.00
# 12  Manchester City    96   704             239  33.9        18.53
# 13   Manchester Utd    56   505             179  35.4        13.29
# ...

# %%
Shooting_a = Shooting.drop('Club',axis=1)

# %%
Shooting_a[Shooting_a.columns] = Shooting_a[Shooting_a.columns].astype(float)

# %%
Shooting_a['Club'] = Shooting['Club']

# %%
Shooting = Shooting_a

# %%
Shooting.to_csv('../Datasets/PL/Shooting-mod.csv')

# %% [markdown]
# ![Screenshot%20%2828%29.png](attachment:Screenshot%20%2828%29.png)

# %% [markdown]
# ![Screenshot%20%2829%29.png](attachment:Screenshot%20%2829%29.png)

# %% [markdown]
# ![Screenshot%20%2830%29.png](attachment:Screenshot%20%2830%29.png)

# %% [markdown]
# ![Screenshot%20%2831%29.png](attachment:Screenshot%20%2831%29.png)

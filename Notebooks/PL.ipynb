# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
players = pd.read_csv('../Datasets/PL/Players.csv')

# %%
players
# Out:
#     Unnamed: 0            Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0           Rk                Player     Nation        Pos            Squad
# 1            1            Max Aarons    eng ENG         DF     Norwich City
# 2            2             Che Adams    sct SCO         FW      Southampton
# 3            3       Rayan Aït Nouri     fr FRA         DF           Wolves
# 4            4       Kristoffer Ajer     no NOR         DF        Brentford
# ..         ...                   ...        ...        ...              ...
# 542        542  Christoph Zimmermann     de GER         DF     Norwich City
# 543        543   Oleksandr Zinchenko     ua UKR         DF  Manchester City
# 544        544          Hakim Ziyech     ma MAR       FWMF          Chelsea
# 545        545            Kurt Zouma     fr FRA         DF         West Ham
# 546        546       Martin Ødegaard     no NOR         MF          Arsenal
#
#     Unnamed: 5 Unnamed: 6 Playing Time Playing Time.1 Playing Time.2  ...  \
# 0          Age       Born           MP         Starts            Min  ...
# 1           21       2000           34             32           2881  ...
# 2           25       1996           30             23           2039  ...
# 3           20       2001           23             20           1828  ...
# 4           23       1998           24             23           1995  ...
# ..         ...        ...          ...            ...            ...  ...
# 542         28       1993            3              2            157  ...
# 543         24       1996           15             10           1047  ...
# 544         28       1993           23             14           1319  ...
# 545         26       1994           24             24           2078  ...
# 546         22       1998           36             32           2785  ...
#
#     Expected.1 Expected.2 Expected.3 Per 90 Minutes.5 Per 90 Minutes.6  \
# 0         npxG         xA    npxG+xA               xG               xA
# 1          0.7        1.4        2.1             0.02             0.04
# 2          7.1        2.6        9.7             0.31             0.12
# 3          0.7        1.3        2.1             0.04             0.07
# 4          0.8        1.4        2.2             0.04             0.06
# ..         ...        ...        ...              ...              ...
# 542        0.1        0.0        0.1             0.04             0.00
# 543        0.4        2.0        2.5             0.04             0.18
# 544        3.4        3.5        6.9             0.23             0.24
# 545        0.9        0.0        0.9             0.04             0.00
# 546        4.8        6.8       11.6             0.16             0.22
#
#     Per 90 Minutes.7 Per 90 Minutes.8 Per 90 Minutes.9 Unnamed: 32 -additional
# 0              xG+xA             npxG          npxG+xA     Matches       -9999
# 1               0.07             0.02             0.07     Matches    774cf58b
# 2               0.43             0.31             0.43     Matches    f2bf1b0f
# 3               0.10             0.04             0.10     Matches    9b398aea
# 4               0.10             0.04             0.10     Matches    a8c0acb7
# ..               ...              ...              ...         ...         ...
# 542             0.04             0.04             0.04     Matches    2d5f03bf
# 543             0.21             0.04             0.21     Matches    51cf8561
# 544             0.47             0.23             0.47     Matches    6622454d
# 545             0.04             0.04             0.04     Matches    ce4246f5
# 546             0.38             0.16             0.38     Matches    79300479
#
# [547 rows x 34 columns]

# %%
players.iloc[0].values
# Out:
# array(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP',
#        'Starts', 'Min', '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt',
#        'CrdY', 'CrdR', 'Gls', 'Ast', 'G+A', 'G-PK', 'G+A-PK', 'xG',
#        'npxG', 'xA', 'npxG+xA', 'xG', 'xA', 'xG+xA', 'npxG', 'npxG+xA',
#        'Matches', '-9999'], dtype=object)

# %%
players.columns = players.iloc[0].values

# %%
players
# Out:
#       Rk                Player   Nation   Pos            Squad  Age  Born  MP  \
# 0     Rk                Player   Nation   Pos            Squad  Age  Born  MP
# 1      1            Max Aarons  eng ENG    DF     Norwich City   21  2000  34
# 2      2             Che Adams  sct SCO    FW      Southampton   25  1996  30
# 3      3       Rayan Aït Nouri   fr FRA    DF           Wolves   20  2001  23
# 4      4       Kristoffer Ajer   no NOR    DF        Brentford   23  1998  24
# ..   ...                   ...      ...   ...              ...  ...   ...  ..
# 542  542  Christoph Zimmermann   de GER    DF     Norwich City   28  1993   3
# 543  543   Oleksandr Zinchenko   ua UKR    DF  Manchester City   24  1996  15
# 544  544          Hakim Ziyech   ma MAR  FWMF          Chelsea   28  1993  23
# 545  545            Kurt Zouma   fr FRA    DF         West Ham   26  1994  24
# 546  546       Martin Ødegaard   no NOR    MF          Arsenal   22  1998  36
#
#      Starts   Min  ...  npxG   xA  npxG+xA    xG    xA  xG+xA  npxG  npxG+xA  \
# 0    Starts   Min  ...  npxG   xA  npxG+xA    xG    xA  xG+xA  npxG  npxG+xA
# 1        32  2881  ...   0.7  1.4      2.1  0.02  0.04   0.07  0.02     0.07
# 2        23  2039  ...   7.1  2.6      9.7  0.31  0.12   0.43  0.31     0.43
# 3        20  1828  ...   0.7  1.3      2.1  0.04  0.07   0.10  0.04     0.10
# 4        23  1995  ...   0.8  1.4      2.2  0.04  0.06   0.10  0.04     0.10
# ..      ...   ...  ...   ...  ...      ...   ...   ...    ...   ...      ...
# 542       2   157  ...   0.1  0.0      0.1  0.04  0.00   0.04  0.04     0.04
# 543      10  1047  ...   0.4  2.0      2.5  0.04  0.18   0.21  0.04     0.21
# 544      14  1319  ...   3.4  3.5      6.9  0.23  0.24   0.47  0.23     0.47
# 545      24  2078  ...   0.9  0.0      0.9  0.04  0.00   0.04  0.04     0.04
# 546      32  2785  ...   4.8  6.8     11.6  0.16  0.22   0.38  0.16     0.38
#
#      Matches     -9999
# 0    Matches     -9999
# 1    Matches  774cf58b
# 2    Matches  f2bf1b0f
# 3    Matches  9b398aea
# 4    Matches  a8c0acb7
# ..       ...       ...
# 542  Matches  2d5f03bf
# 543  Matches  51cf8561
# 544  Matches  6622454d
# 545  Matches  ce4246f5
# 546  Matches  79300479
#
# [547 rows x 34 columns]

# %%
players = players.iloc[1:]

# %%
players.index = players['Rk']

# %%
players.drop('Rk',axis=1,inplace=True)

# %%
players
# Out:
#                    Player   Nation   Pos            Squad Age  Born  MP  \
# Rk
# 1              Max Aarons  eng ENG    DF     Norwich City  21  2000  34
# 2               Che Adams  sct SCO    FW      Southampton  25  1996  30
# 3         Rayan Aït Nouri   fr FRA    DF           Wolves  20  2001  23
# 4         Kristoffer Ajer   no NOR    DF        Brentford  23  1998  24
# 5              Nathan Aké   nl NED    DF  Manchester City  26  1995  14
# ..                    ...      ...   ...              ...  ..   ...  ..
# 542  Christoph Zimmermann   de GER    DF     Norwich City  28  1993   3
# 543   Oleksandr Zinchenko   ua UKR    DF  Manchester City  24  1996  15
# 544          Hakim Ziyech   ma MAR  FWMF          Chelsea  28  1993  23
# 545            Kurt Zouma   fr FRA    DF         West Ham  26  1994  24
# 546       Martin Ødegaard   no NOR    MF          Arsenal  22  1998  36
#
#     Starts   Min   90s  ... npxG   xA npxG+xA    xG    xA xG+xA  npxG npxG+xA  \
# Rk                      ...
# 1       32  2881  32.0  ...  0.7  1.4     2.1  0.02  0.04  0.07  0.02    0.07
# 2       23  2039  22.7  ...  7.1  2.6     9.7  0.31  0.12  0.43  0.31    0.43
# 3       20  1828  20.3  ...  0.7  1.3     2.1  0.04  0.07  0.10  0.04    0.10
# 4       23  1995  22.2  ...  0.8  1.4     2.2  0.04  0.06  0.10  0.04    0.10
# 5       10   923  10.3  ...  1.1  0.5     1.6  0.11  0.05  0.16  0.11    0.16
# ..     ...   ...   ...  ...  ...  ...     ...   ...   ...   ...   ...     ...
# 542      2   157   1.7  ...  0.1  0.0     0.1  0.04  0.00  0.04  0.04    0.04
# 543     10  1047  11.6  ...  0.4  2.0     2.5  0.04  0.18  0.21  0.04    0.21
# 544     14  1319  14.7  ...  3.4  3.5     6.9  0.23  0.24  0.47  0.23    0.47
# 545     24  2078  23.1  ...  0.9  0.0     0.9  0.04  0.00  0.04  0.04    0.04
# 546     32  2785  30.9  ...  4.8  6.8    11.6  0.16  0.22  0.38  0.16    0.38
#
#      Matches     -9999
# Rk
# 1    Matches  774cf58b
# 2    Matches  f2bf1b0f
# 3    Matches  9b398aea
# 4    Matches  a8c0acb7
# 5    Matches  eaeca114
# ..       ...       ...
# 542  Matches  2d5f03bf
# 543  Matches  51cf8561
# 544  Matches  6622454d
# 545  Matches  ce4246f5
# 546  Matches  79300479
#
# [546 rows x 33 columns]

# %%
players.iloc[:,-2:]
# Out:
#      Matches     -9999
# Rk
# 1    Matches  774cf58b
# 2    Matches  f2bf1b0f
# 3    Matches  9b398aea
# 4    Matches  a8c0acb7
# 5    Matches  eaeca114
# ..       ...       ...
# 542  Matches  2d5f03bf
# 543  Matches  51cf8561
# 544  Matches  6622454d
# 545  Matches  ce4246f5
# 546  Matches  79300479
#
# [546 rows x 2 columns]

# %%
players.drop(players.iloc[:,-2:], axis=1, inplace=True)

# %%
players
# Out:
#                    Player   Nation   Pos            Squad Age  Born  MP  \
# Rk
# 1              Max Aarons  eng ENG    DF     Norwich City  21  2000  34
# 2               Che Adams  sct SCO    FW      Southampton  25  1996  30
# 3         Rayan Aït Nouri   fr FRA    DF           Wolves  20  2001  23
# 4         Kristoffer Ajer   no NOR    DF        Brentford  23  1998  24
# 5              Nathan Aké   nl NED    DF  Manchester City  26  1995  14
# ..                    ...      ...   ...              ...  ..   ...  ..
# 542  Christoph Zimmermann   de GER    DF     Norwich City  28  1993   3
# 543   Oleksandr Zinchenko   ua UKR    DF  Manchester City  24  1996  15
# 544          Hakim Ziyech   ma MAR  FWMF          Chelsea  28  1993  23
# 545            Kurt Zouma   fr FRA    DF         West Ham  26  1994  24
# 546       Martin Ødegaard   no NOR    MF          Arsenal  22  1998  36
#
#     Starts   Min   90s  ... G+A-PK   xG npxG   xA npxG+xA    xG    xA xG+xA  \
# Rk                      ...
# 1       32  2881  32.0  ...   0.06  0.7  0.7  1.4     2.1  0.02  0.04  0.07
# 2       23  2039  22.7  ...   0.44  7.1  7.1  2.6     9.7  0.31  0.12  0.43
# 3       20  1828  20.3  ...   0.15  0.7  0.7  1.3     2.1  0.04  0.07  0.10
# 4       23  1995  22.2  ...   0.18  0.8  0.8  1.4     2.2  0.04  0.06  0.10
# 5       10   923  10.3  ...   0.20  1.1  1.1  0.5     1.6  0.11  0.05  0.16
# ..     ...   ...   ...  ...    ...  ...  ...  ...     ...   ...   ...   ...
# 542      2   157   1.7  ...   0.00  0.1  0.1  0.0     0.1  0.04  0.00  0.04
# 543     10  1047  11.6  ...   0.34  0.4  0.4  2.0     2.5  0.04  0.18  0.21
# 544     14  1319  14.7  ...   0.48  3.4  3.4  3.5     6.9  0.23  0.24  0.47
# 545     24  2078  23.1  ...   0.04  0.9  0.9  0.0     0.9  0.04  0.00  0.04
# 546     32  2785  30.9  ...   0.36  4.8  4.8  6.8    11.6  0.16  0.22  0.38
#
#      npxG npxG+xA
# Rk
# 1    0.02    0.07
# 2    0.31    0.43
# 3    0.04    0.10
# 4    0.04    0.10
# 5    0.11    0.16
# ..    ...     ...
# 542  0.04    0.04
# 543  0.04    0.21
# 544  0.23    0.47
# 545  0.04    0.04
# 546  0.16    0.38
#
# [546 rows x 31 columns]

# %%
players.Nation.unique()
# Out:
# array(['eng ENG', 'sct SCO', 'fr FRA', 'no NOR', 'nl NED', 'es ESP',
#        'br BRA', 'py PAR', 'co COL', 'gh GHA', 'dk DEN', 'jm JAM',
#        'ga GAB', 'at AUT', 'ci CIV', 'gd GRN', 'pl POL', 'ba BIH',
#        'dz ALG', 'uy URU', 'be BEL', 'is ISL', 'ml MLI', 'al ALB',
#        'ar ARG', 'ec ECU', 'wls WAL', 'pt POR', 'nir NIR', 'ie IRL',
#        'ao ANG', 'cz CZE', 'zm ZAM', 'ng NGA', 'sk SVK', 'se SWE',
#        'eg EGY', 'fi FIN', 'ir IRN', 'gr GRE', 'de GER', 'kr KOR',
#        'mx MEX', 'it ITA', 'tr TUR', 'cd COD', 'gn GUI', 'sn SEN',
#        'hr CRO', 'ma MAR', 'rs SRB', 'cm CMR', 'tn TUN', 'jp JPN',
#        'ua UKR', 'zw ZIM', 'us USA', 'xk KVX', 've VEN', 'ch SUI',
#        'cl CHI', 'bf BFA', 'nz NZL'], dtype=object)

# %%
idxs = players.Nation.str.index(' ')

# %%
players.Nation[0][4:]
# Out:
# 'ENG'

# %%
idxs
# Out:
# Rk
# 1      3
# 2      3
# 3      2
# 4      2
# 5      2
#       ..
# 542    2
# 543    2
# 544    2
# 545    2
# 546    2
# Name: Nation, Length: 546, dtype: int64

# %%
len(idxs)
# Out:
# 546

# %%
i=0
r=[]
while i<len(idxs):
    r.append(players.Nation[i][idxs[i]+1:])
    i+=1

# %%
r[:10]
# Out:
# ['ENG', 'SCO', 'FRA', 'NOR', 'NED', 'ENG', 'ESP', 'ENG', 'BRA', 'BRA']

# %%
players.Nation = r

# %%
players
# Out:
#                    Player Nation   Pos            Squad Age  Born  MP Starts  \
# Rk
# 1              Max Aarons    ENG    DF     Norwich City  21  2000  34     32
# 2               Che Adams    SCO    FW      Southampton  25  1996  30     23
# 3         Rayan Aït Nouri    FRA    DF           Wolves  20  2001  23     20
# 4         Kristoffer Ajer    NOR    DF        Brentford  23  1998  24     23
# 5              Nathan Aké    NED    DF  Manchester City  26  1995  14     10
# ..                    ...    ...   ...              ...  ..   ...  ..    ...
# 542  Christoph Zimmermann    GER    DF     Norwich City  28  1993   3      2
# 543   Oleksandr Zinchenko    UKR    DF  Manchester City  24  1996  15     10
# 544          Hakim Ziyech    MAR  FWMF          Chelsea  28  1993  23     14
# 545            Kurt Zouma    FRA    DF         West Ham  26  1994  24     24
# 546       Martin Ødegaard    NOR    MF          Arsenal  22  1998  36     32
#
#       Min   90s  ... G+A-PK   xG npxG   xA npxG+xA    xG    xA xG+xA  npxG  \
# Rk               ...
# 1    2881  32.0  ...   0.06  0.7  0.7  1.4     2.1  0.02  0.04  0.07  0.02
# 2    2039  22.7  ...   0.44  7.1  7.1  2.6     9.7  0.31  0.12  0.43  0.31
# 3    1828  20.3  ...   0.15  0.7  0.7  1.3     2.1  0.04  0.07  0.10  0.04
# 4    1995  22.2  ...   0.18  0.8  0.8  1.4     2.2  0.04  0.06  0.10  0.04
# 5     923  10.3  ...   0.20  1.1  1.1  0.5     1.6  0.11  0.05  0.16  0.11
# ..    ...   ...  ...    ...  ...  ...  ...     ...   ...   ...   ...   ...
# 542   157   1.7  ...   0.00  0.1  0.1  0.0     0.1  0.04  0.00  0.04  0.04
# 543  1047  11.6  ...   0.34  0.4  0.4  2.0     2.5  0.04  0.18  0.21  0.04
# 544  1319  14.7  ...   0.48  3.4  3.4  3.5     6.9  0.23  0.24  0.47  0.23
# 545  2078  23.1  ...   0.04  0.9  0.9  0.0     0.9  0.04  0.00  0.04  0.04
# 546  2785  30.9  ...   0.36  4.8  4.8  6.8    11.6  0.16  0.22  0.38  0.16
#
#     npxG+xA
# Rk
# 1      0.07
# 2      0.43
# 3      0.10
# 4      0.10
# 5      0.16
# ..      ...
# 542    0.04
# 543    0.21
# 544    0.47
# 545    0.04
# 546    0.38
#
# [546 rows x 31 columns]

# %%
players.Pos.unique()
# Out:
# array(['DF', 'FW', 'FWDF', 'MF', 'GK', 'MFFW', 'FWMF', 'DFMF', 'MFDF',
#        'DFFW'], dtype=object)

# %%
idxs = np.where(leplayers.Pos
